# %% [markdown]
# # Notebook summary
# This notebook is used to extract skeleton data from the set of snatch lifts with EffNetV2.
#
# Structure:
# - Load libraries
# - Get cluster settups
# - Load data
# - Load model
# - Define utils function
#
# Output:
# - json annotation files for each sample
# - zip file with pressed output

# %% [markdown]
# # Load libraries

# %%
import torch
import os

from typing import Generator, Optional, Tuple

import matplotlib.pyplot as plt
import numpy as np

import cv2

from dataclasses import dataclass

import tensorflow as tf
import tensorflow_hub as hub

from google.colab import files

from tqdm.notebook import tqdm
import json

# %% [markdown]
# # Get cluster setup

# %%
# !nvidia-smi
# Out:
# Mon Nov 18 17:45:25 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# !nvcc --version
TORCH_VERSION = ".".join(torch.__version__.split(".")[:2])
CUDA_VERSION = torch.__version__.split("+")[-1]
print("torch: ", TORCH_VERSION, "; cuda: ", CUDA_VERSION)
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0
# torch:  2.5 ; cuda:  cu121

# %%
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# # Load data

# %%
# %cd {HOME}
# !mkdir input
# %cd {HOME}/input
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1DyZsR-1sQzCa7-tk-GnGzYdnrroHscsU' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1DyZsR-1sQzCa7-tk-GnGzYdnrroHscsU" -O sample-0.mp4 && rm -rf /tmp/cookies.txt
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=14PdKHaVeaAzLNHeWEJW506_ACQJk84IB' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=14PdKHaVeaAzLNHeWEJW506_ACQJk84IB" -O sample-1.mp4 && rm -rf /tmp/cookies.txt
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1JEqXkLwpOxZ80cVBfo7efCOzTG17wA4B' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1JEqXkLwpOxZ80cVBfo7efCOzTG17wA4B" -O sample-2.mp4 && rm -rf /tmp/cookies.txt
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1Vn39BQ5F49Fgm9bxruaRz3Q100to6VCJ' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1Vn39BQ5F49Fgm9bxruaRz3Q100to6VCJ" -O sample-3.mp4 && rm -rf /tmp/cookies.txt
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1mp1mg0xe7NTdjixo81U9bcELykQCaCGh' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1mp1mg0xe7NTdjixo81U9bcELykQCaCGh" -O sample-4.mp4 && rm -rf /tmp/cookies.txt
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1o7P71WTGivEsrVKA4tHyCvsuCaub-_yy' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1o7P71WTGivEsrVKA4tHyCvsuCaub-_yy" -O sample-5.mp4 && rm -rf /tmp/cookies.txt
# Out:
# /content
# /content/input
# --2024-11-18 17:45:29--  https://docs.google.com/uc?export=download&confirm=&id=1DyZsR-1sQzCa7-tk-GnGzYdnrroHscsU
# Resolving docs.google.com (docs.google.com)... 142.250.4.100, 142.250.4.138, 142.250.4.102, ...
# Connecting to docs.google.com (docs.google.com)|142.250.4.100|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1DyZsR-1sQzCa7-tk-GnGzYdnrroHscsU&export=download [following]
# --2024-11-18 17:45:29--  https://drive.usercontent.google.com/download?id=1DyZsR-1sQzCa7-tk-GnGzYdnrroHscsU&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 142.251.12.132, 2404:6800:4003:c02::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|142.251.12.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1355630 (1.3M) [video/mp4]
# Saving to: ‘sample-0.mp4’
#
# sample-0.mp4        100%[===================>]   1.29M  --.-KB/s    in 0.01s
#
# 2024-11-18 17:45:32 (112 MB/s) - ‘sample-0.mp4’ saved [1355630/1355630]
#
# --2024-11-18 17:45:35--  https://docs.google.com/uc?export=download&confirm=&id=14PdKHaVeaAzLNHeWEJW506_ACQJk84IB
# Resolving docs.google.com (docs.google.com)... 142.250.4.100, 142.250.4.138, 142.250.4.102, ...
# Connecting to docs.google.com (docs.google.com)|142.250.4.100|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=14PdKHaVeaAzLNHeWEJW506_ACQJk84IB&export=download [following]
# --2024-11-18 17:45:35--  https://drive.usercontent.google.com/download?id=14PdKHaVeaAzLNHeWEJW506_ACQJk84IB&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 142.251.12.132, 2404:6800:4003:c02::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|142.251.12.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1036632 (1012K) [video/mp4]
# Saving to: ‘sample-1.mp4’
#
# sample-1.mp4        100%[===================>]   1012K  --.-KB/s    in 0.008s
#
# 2024-11-18 17:45:39 (125 MB/s) - ‘sample-1.mp4’ saved [1036632/1036632]
#
# --2024-11-18 17:45:42--  https://docs.google.com/uc?export=download&confirm=&id=1JEqXkLwpOxZ80cVBfo7efCOzTG17wA4B
# Resolving docs.google.com (docs.google.com)... 142.250.4.100, 142.250.4.138, 142.250.4.102, ...
# Connecting to docs.google.com (docs.google.com)|142.250.4.100|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1JEqXkLwpOxZ80cVBfo7efCOzTG17wA4B&export=download [following]
# --2024-11-18 17:45:42--  https://drive.usercontent.google.com/download?id=1JEqXkLwpOxZ80cVBfo7efCOzTG17wA4B&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 142.251.12.132, 2404:6800:4003:c02::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|142.251.12.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1580694 (1.5M) [video/mp4]
# Saving to: ‘sample-2.mp4’
#
# sample-2.mp4        100%[===================>]   1.51M  --.-KB/s    in 0.01s
#
# 2024-11-18 17:45:44 (153 MB/s) - ‘sample-2.mp4’ saved [1580694/1580694]
#
# --2024-11-18 17:45:48--  https://docs.google.com/uc?export=download&confirm=&id=1Vn39BQ5F49Fgm9bxruaRz3Q100to6VCJ
# Resolving docs.google.com (docs.google.com)... 142.250.4.100, 142.250.4.138, 142.250.4.102, ...
# Connecting to docs.google.com (docs.google.com)|142.250.4.100|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1Vn39BQ5F49Fgm9bxruaRz3Q100to6VCJ&export=download [following]
# --2024-11-18 17:45:48--  https://drive.usercontent.google.com/download?id=1Vn39BQ5F49Fgm9bxruaRz3Q100to6VCJ&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 142.251.12.132, 2404:6800:4003:c02::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|142.251.12.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 751668 (734K) [video/mp4]
# Saving to: ‘sample-3.mp4’
#
# sample-3.mp4        100%[===================>] 734.05K  --.-KB/s    in 0.005s
#
# 2024-11-18 17:45:51 (153 MB/s) - ‘sample-3.mp4’ saved [751668/751668]
#
# --2024-11-18 17:45:55--  https://docs.google.com/uc?export=download&confirm=&id=1mp1mg0xe7NTdjixo81U9bcELykQCaCGh
# Resolving docs.google.com (docs.google.com)... 142.251.10.100, 142.251.10.101, 142.251.10.138, ...
# Connecting to docs.google.com (docs.google.com)|142.251.10.100|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1mp1mg0xe7NTdjixo81U9bcELykQCaCGh&export=download [following]
# --2024-11-18 17:45:56--  https://drive.usercontent.google.com/download?id=1mp1mg0xe7NTdjixo81U9bcELykQCaCGh&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 74.125.200.132, 2404:6800:4003:c05::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|74.125.200.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1110866 (1.1M) [video/mp4]
# Saving to: ‘sample-4.mp4’
#
# sample-4.mp4        100%[===================>]   1.06M  --.-KB/s    in 0.008s
#
# 2024-11-18 17:45:59 (140 MB/s) - ‘sample-4.mp4’ saved [1110866/1110866]
#
# --2024-11-18 17:46:02--  https://docs.google.com/uc?export=download&confirm=&id=1o7P71WTGivEsrVKA4tHyCvsuCaub-_yy
# Resolving docs.google.com (docs.google.com)... 142.251.10.100, 142.251.10.101, 142.251.10.138, ...
# Connecting to docs.google.com (docs.google.com)|142.251.10.100|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1o7P71WTGivEsrVKA4tHyCvsuCaub-_yy&export=download [following]
# --2024-11-18 17:46:02--  https://drive.usercontent.google.com/download?id=1o7P71WTGivEsrVKA4tHyCvsuCaub-_yy&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 74.125.200.132, 2404:6800:4003:c05::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|74.125.200.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 850835 (831K) [video/mp4]
# Saving to: ‘sample-5.mp4’
#
# sample-5.mp4        100%[===================>] 830.89K  --.-KB/s    in 0.005s
#
# 2024-11-18 17:46:05 (154 MB/s) - ‘sample-5.mp4’ saved [850835/850835]

# %%
SOURCE_VIDEO_0_PATH = f"{HOME}/input/sample-0.mp4"
SOURCE_VIDEO_1_PATH = f"{HOME}/input/sample-1.mp4"
SOURCE_VIDEO_2_PATH = f"{HOME}/input/sample-2.mp4"
SOURCE_VIDEO_3_PATH = f"{HOME}/input/sample-3.mp4"
SOURCE_VIDEO_4_PATH = f"{HOME}/input/sample-4.mp4"
SOURCE_VIDEO_5_PATH = f"{HOME}/input/sample-5.mp4"

# %% [markdown]
# # Load model

# %%
model = hub.load('https://bit.ly/metrabs_xl')  # Takes about 3 minutes

# %% [markdown]
# # Define utils function

# %%
# %matplotlib inline


def generate_frames(video_file: str) -> Generator[np.ndarray, None, None]:
    video = cv2.VideoCapture(video_file)

    while video.isOpened():
        success, frame = video.read()

        if not success:
            break

        yield frame

    video.release()


def plot_image(image: np.ndarray, size: int = 12) -> None:
    plt.figure(figsize=(size, size))
    plt.axis('off')
    plt.imshow(image[...,::-1])
    plt.show()

# %%
@dataclass(frozen=True)
class Point:
    x: float
    y: float

    @property
    def int_xy_tuple(self) -> Tuple[int, int]:
        return int(self.x), int(self.y)


@dataclass(frozen=True)
class Rect:
    x: float
    y: float
    width: float
    height: float

    @property
    def top_left(self) -> Point:
        return Point(x=self.x, y=self.y)

    @property
    def bottom_right(self) -> Point:
        return Point(x=self.x + self.width, y=self.y + self.height)

    @property
    def bottom_center(self) -> Point:
        return Point(x=self.x + self.width / 2, y=self.y + self.height)

@dataclass
class Detection:
    rect: Rect
    class_id: int
    confidence: float
    tracker_id: Optional[int] = None


@dataclass(frozen=True)
class Color:
    r: int
    g: int
    b: int

    @property
    def bgr_tuple(self) -> Tuple[int, int, int]:
        return self.b, self.g, self.r

# %%
def draw_rect(image: np.ndarray, rect: Rect, color: Color, thickness: int = 2) -> np.ndarray:
    cv2.rectangle(image, rect.top_left.int_xy_tuple, rect.bottom_right.int_xy_tuple, color.bgr_tuple, thickness)
    return image

# %%
@dataclass(frozen=True)
class VideoConfig:
    fps: float
    width: int
    height: int


# create cv2.VideoWriter object that we can use to save output video
def get_video_writer(target_video_path: str, video_config: VideoConfig) -> cv2.VideoWriter:
    video_target_dir = os.path.dirname(os.path.abspath(target_video_path))
    os.makedirs(video_target_dir, exist_ok=True)
    return cv2.VideoWriter(
        target_video_path,
        fourcc=cv2.VideoWriter_fourcc(*"mp4v"),
        fps=video_config.fps,
        frameSize=(video_config.width, video_config.height),
        isColor=True
    )


def get_frame_count(path: str) -> int:
    cap = cv2.VideoCapture(path)
    return int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

# %% [markdown]
# ## Test data and utils

# %%
frame_iterator = iter(generate_frames(video_file=SOURCE_VIDEO_1_PATH))

frame = next(frame_iterator)
plot_image(frame, 16)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Data extraction

# %%
directory_path = "/content/drive/MyDrive/master_thesis/input/test_data/mpi_inf_3dhp_17-annotations/"
if not os.path.exists(directory_path):
    os.makedirs(directory_path)
    print(f"Directory created: {directory_path}")

for sample in list(range(6)):
    results_dictionary = {}
    SOURCE_VIDEO_PATH = f"/content/input/sample-{sample}.mp4"
    TARGET_VIDEO_PATH = f"{HOME}/output/output-sample-{sample}.mp4"
    file_path = f"/content/drive/MyDrive/master_thesis/input/test_data/mpi_inf_3dhp_17-annotations/sample-{sample}.json"

    cap = cv2.VideoCapture(SOURCE_VIDEO_PATH)

    video_config = VideoConfig(
      fps=25,
      width=int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)),
      height=int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)))
    video_writer = get_video_writer(
      target_video_path=TARGET_VIDEO_PATH,
      video_config=video_config)

  # get fresh video frame generator
    frame_iterator = iter(generate_frames(video_file=SOURCE_VIDEO_PATH))

    total = get_frame_count(SOURCE_VIDEO_PATH)
    frame_number = 0

    for frame in tqdm(frame_iterator, total=total):
      annotated_frame = frame.copy()

      with torch.no_grad():
          results = model.detect_poses(frame, skeleton='mpi_inf_3dhp_17')
          # Convert EagerTensors to lists or NumPy arrays
          for key, value in results.items():
              if isinstance(value, type(tf.constant(0))):  # if value is an EagerTensor
                  results[key] = value.numpy().tolist() # convert to NumPy array and then to list
          results_dictionary[f'frame_{frame_number}'] = results
          frame_number += 1

    with open(file_path, "w") as file:
        json.dump(results_dictionary, file)
# Out:
# Directory created: /content/drive/MyDrive/master_thesis/input/test_data/mpi_inf_3dhp_17-annotations/
#   0%|          | 0/145 [00:00<?, ?it/s]
#   0%|          | 0/107 [00:00<?, ?it/s]
#   0%|          | 0/163 [00:00<?, ?it/s]
#   0%|          | 0/88 [00:00<?, ?it/s]
#   0%|          | 0/138 [00:00<?, ?it/s]
#   0%|          | 0/96 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]

# %%
joint_names = model.per_skeleton_joint_names['mpi_inf_3dhp_17'].numpy().astype(str).tolist()
joint_edges = model.per_skeleton_joint_edges['mpi_inf_3dhp_17'].numpy().tolist()

# %%
joint_names
# Out:
# ['htop',
#  'neck',
#  'rsho',
#  'relb',
#  'rwri',
#  'lsho',
#  'lelb',
#  'lwri',
#  'rhip',
#  'rkne',
#  'rank',
#  'lhip',
#  'lkne',
#  'lank',
#  'pelv',
#  'spin',
#  'head']

# %%
joint_names_path = "/content/drive/MyDrive/master_thesis/input/test_data/mpi_inf_3dhp_17-annotations/joint_names.json"
joint_edges_path = "/content/drive/MyDrive/master_thesis/input/test_data/mpi_inf_3dhp_17-annotations/joint_edges.json"


with open(joint_names_path, "w") as file:
        json.dump(joint_names, file)

with open(joint_edges_path, "w") as file:
        json.dump(joint_edges, file)
